# %% [markdown]
# # 0. Readme
#
# 这个文件包含了整个数理统计数据分析的流程。运行这个文件，将得到所有的结果。

# %%
import sys
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# 设置英文字体
plt.rcParams['font.family'] = ['SimSun', 'Times New Roman']
plt.rcParams['font.size'] = 10.5  # 设置字体大小

# 设置中文字体
fontproperties = FontProperties(fname='C:\\Windows\\Fonts\\simsun.ttc')

# 配色
color_red = (219 / 255, 49 / 255, 36 / 255)
color_orange = (252 / 255, 140 / 255, 90 / 255)
color_yellow = (255 / 255, 223 / 255, 146 / 255)
color_gray = (230 / 255, 241 / 255, 243 / 255)
color_light_blue = (144 / 255, 190 / 255, 224 / 255)
color_dark_blue = (75 / 255, 116 / 255, 178 / 255)

# 将项目主文件夹加入到环境变量，方便导入src的内容
sys.path.append("..")

# %% [markdown]
# # 1. 数据读取和预处理
#
# 读取收集到的csv数据，会发现其中的 **urban_population_rate** 一列缺少两个数据，于是需要对数据进行处理。
#
# 预处理时采用插值法补全数据。

# %%
import os
import pandas as pd

proj_dir = os.path.abspath("..")
data_path = os.path.join(proj_dir, "data", "data.csv")
save_path = os.path.join(proj_dir, "reports")

# 读取数据并预处理
from src.data_preprocess import read_population_data, do_standardize, inverse_standardize
df = read_population_data(data_path)
df
# Out:
#       population  urban_population_rate  gdp_per_capita  unemployment_rate
# year
# 2001     2829.00              34.710000          5655.0               3.90
# 2002     2814.00              36.400000          6353.0               4.10
# 2003     2803.00              39.333333          8075.0               4.10
# 2004     2793.00              42.266667          9608.0               4.10
# 2005     2798.00              45.200000         10978.0               4.10
# 2006     2808.00              46.700000         12437.0               4.00
# 2007     2816.00              48.300000         14622.0               3.90
# 2008     2839.00              49.990000         20490.0               3.96
# 2009     2859.00              51.590000         22920.0               3.96
# 2010     2885.00              53.020000         27596.0               3.90
# 2011     2919.00              55.020000         34500.0               3.50
# ...

# %%
# 进行数据标准化
std_df = do_standardize(df)
std_df.to_csv(os.path.join(proj_dir, "data", "std_data.csv"))
std_df
# Out:
#       population  urban_population_rate  gdp_per_capita  unemployment_rate
# year
# 2001   -0.973606              -1.871920       -1.253572           0.098822
# 2002   -1.067028              -1.722288       -1.229586           0.405970
# 2003   -1.135538              -1.462572       -1.170412           0.405970
# 2004   -1.197819              -1.202856       -1.117732           0.405970
# 2005   -1.166679              -0.943139       -1.070654           0.405970
# 2006   -1.104397              -0.810330       -1.020517           0.252396
# 2007   -1.054572              -0.668667       -0.945433           0.098822
# 2008   -0.911324              -0.519035       -0.743786           0.190966
# 2009   -0.786761              -0.377371       -0.660282           0.190966
# 2010   -0.624828              -0.250760       -0.499598           0.098822
# 2011   -0.413071              -0.073680       -0.262351          -0.515475
# ...

# %%
# 保存描述性统计分析表
print(df.quantile())
df.describe().to_csv(os.path.join(save_path, 'df_describe.csv'))


print(std_df.quantile())
std_df.describe().to_csv(os.path.join(save_path, 'std_df_describe.csv'))
# Out:
# population                2945.00
# urban_population_rate       56.98
# gdp_per_capita           38914.00
# unemployment_rate            3.90
# Name: 0.5, dtype: float64
# population              -0.251139
# urban_population_rate    0.099857
# gdp_per_capita          -0.110669
# unemployment_rate        0.098822
# Name: 0.5, dtype: float64
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[150], line 7
#       3 df.describe().to_csv(os.path.join(save_path, 'df_describe.csv'))
#       6 print(std_df.quantile())
# ----> 7 std_df.describe().to_csv(os.path.join(save_path, 'std_df_describe.csv'))
#
# File D:\Applications\miniconda3\envs\ml\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
# ...

# %%
# 描述性统计分析

# 标准化后的盒图
colors = [color_red, color_yellow, color_light_blue, color_dark_blue]

fig, ax = plt.subplots(figsize=(8, 6))

bplot = ax.boxplot(std_df, vert=True, patch_artist=True,
                       boxprops=dict(linestyle='-', linewidth=4, color='k'),
                       flierprops=dict(linestyle='-', linewidth=4, color='k'),
                       medianprops=dict(linestyle='-', linewidth=4, color='k'),
                       whiskerprops=dict(linestyle='-', linewidth=4, color='k'),
                       capprops=dict(linestyle='-', linewidth=4, color='k'),
                       sym='r+')

for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

ax.yaxis.grid(True)
ax.set_ylabel("标准化数值")

plt.setp(ax, xticks=[1, 2, 3, 4],
         xticklabels=['人口', '城镇人口比重', '人均GDP', '城镇人口失业率'])
plt.tight_layout()
plt.savefig(os.path.join(save_path, 'std_df_box.png'), dpi=600)
plt.show()



# 原始带量纲的盒图
xlabel = ["人口（万人）", "城镇人口比重（%）", "人均GDP（元）", "城镇人口失业率（%）",]

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

for i, ax in enumerate(axs.flatten()):
    bplot = ax.boxplot(df[mapping[i]], vert=True, patch_artist=True,
                       boxprops=dict(linestyle='-', linewidth=4, color='k'),
                       flierprops=dict(linestyle='-', linewidth=4, color='k'),
                       medianprops=dict(linestyle='-', linewidth=4, color='k'),
                       whiskerprops=dict(linestyle='-', linewidth=4, color='k'),
                       capprops=dict(linestyle='-', linewidth=4, color='k'),
                       sym='r+', showmeans=True, )
    bplot['boxes'][0].set_facecolor(colors[i])
    ax.yaxis.grid(True)
    ax.set_xlabel(xlabel[i])
    ax.set_xticks([])
    
plt.tight_layout()
plt.savefig(os.path.join(save_path, 'df_box.png'), dpi=600)
plt.show()

# %%
mapping = {
    0: "population",
    1: "urban_population_rate",
    2: "gdp_per_capita",
    3: "unemployment_rate",
}

chinese = {
    0: "人口（万人）",
    1: "城镇人口比重（%）",
    2: "人均GDP（元）",
    3: "城镇人口失业率（%）",
}

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8,6))
for i, ax in enumerate(axs.flatten()):
    ax.plot(df.index, df[mapping[i]], '--o', linewidth=4, color=colors[i], ms=4, markerfacecolor=color_gray, markeredgecolor='k')
    ax.yaxis.grid(True)
    ax.tick_params(axis='x', labelrotation=62)
    ax.set_xlabel('年份', fontproperties=fontproperties)
    ax.set_ylabel(chinese[i])

plt.tight_layout()
plt.savefig(os.path.join(save_path, 'df_line_chart.png'), dpi=600)
plt.show()

# %% [markdown]
# # 2. 直接进行多元线性回归

# %%
from src.regression import regression

model = regression(std_df, "population", "urban_population_rate", "gdp_per_capita", "unemployment_rate")
print(model.summary())

population_fitted = model.fittedvalues
population_fitted = pd.DataFrame(population_fitted, columns=[mapping[0]])

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(std_df.index, std_df["population"], 'o', label='data', ms=3, color=color_dark_blue)
ax.plot(std_df.index, population_fitted, '--.',label='OLS', color=color_red)
plt.show()

residuals = pd.DataFrame(inverse_standardize(std_df) - inverse_standardize(population_fitted), columns=[mapping[0]])

# print(residuals)

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(std_df.index, residuals, 'x', label='data', ms=4, color=color_red)

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             population   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.971
# Method:                 Least Squares   F-statistic:                     246.0
# Date:                Wed, 15 May 2024   Prob (F-statistic):           2.24e-15
# Time:                        22:20:51   Log-Likelihood:                 9.7407
# No. Observations:                  23   AIC:                            -11.48
# Df Residuals:                      19   BIC:                            -6.940
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              2.959e-15      0.036   8.14e-14      1.000      -0.076       0.076
# ...

# %%
from src.data_preprocess import transform
transfromed_df = transform(std_df)

model = regression(transfromed_df, "population", "urban_population_rate", "gdp_per_capita", "unemployment_rate", "prev_population")
print(model.summary())

population_fitted = model.fittedvalues
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(std_df.index, std_df["population"], 'o', label='data')
ax.plot(std_df.index[1:], population_fitted, 'r--.',label='OLS')
ax.legend(loc='best')
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             population   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     781.8
# Date:                Wed, 15 May 2024   Prob (F-statistic):           5.08e-19
# Time:                        22:20:56   Log-Likelihood:                 26.200
# No. Observations:                  22   AIC:                            -42.40
# Df Residuals:                      17   BIC:                            -36.94
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0877      0.022      3.971      0.001       0.041       0.134
# ...

# %%
from src.data_preprocess import ratio_and_diff, reverse_diff_ratio
ratio_diff_df, ratio_x0, diff_x0 = ratio_and_diff(std_df)
ratio_diff_df

model = regression(ratio_diff_df, "population", "urban_population_rate", "gdp_per_capita", "unemployment_rate")
print(model.summary())

population_fitted = model.fittedvalues
population_fitted = pd.DataFrame({population_fitted.name: population_fitted})
population_fitted.columns = ["population"]

print(ratio_diff_df)
print(population_fitted)
print(ratio_x0)

restored_population_fitted = reverse_diff_ratio(population_fitted, diff_x0, ratio_x0)
print(inverse_standardize(restored_population_fitted))


fig, ax = plt.subplots(figsize=(8,6))
ax.plot(std_df.index, std_df["population"], 'o', label='data')
ax.plot(restored_population_fitted.index[2:], restored_population_fitted["population"][2:], 'r--.',label='OLS')
ax.legend(loc='best')
plt.show()

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(ratio_diff_df.index, ratio_diff_df["population"], 'o', label='data')
ax.plot(population_fitted.index, population_fitted["population"], 'r--.',label='OLS')
ax.legend(loc='best')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             population   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     68.91
# Date:                Wed, 15 May 2024   Prob (F-statistic):           1.02e-09
# Time:                        22:20:59   Log-Likelihood:                 4.4508
# No. Observations:                  21   AIC:                           -0.9015
# Df Residuals:                      17   BIC:                             3.277
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.0126      0.048     -0.265      0.794      -0.113       0.088
# ...

# %%
from src.data_preprocess import do_ratio, reverse_ratio
ratio_df, ratio_x0 = do_ratio(std_df)
ratio_df -= 1

model = regression(ratio_df, "population", "urban_population_rate", "gdp_per_capita", "unemployment_rate")
print(model.summary())

population_fitted = model.fittedvalues
population_fitted = pd.DataFrame({population_fitted.name: population_fitted})
population_fitted.columns = ["population"]

print(ratio_df)
print(population_fitted)

restored_population_fitted = reverse_ratio(population_fitted+1, ratio_x0)
print(restored_population_fitted)


fig, ax = plt.subplots(figsize=(8,6))
ax.plot(std_df.index, std_df["population"], 'o', label='data')
ax.plot(restored_population_fitted.index[1:], restored_population_fitted["population"][1:], 'r--.',label='OLS')
ax.legend(loc='best')
plt.show()

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(ratio_df.index, ratio_df["population"], 'o', label='data')
ax.plot(population_fitted.index, population_fitted["population"], 'r--.',label='OLS')
ax.legend(loc='best')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             population   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     16.43
# Date:                Wed, 15 May 2024   Prob (F-statistic):           2.15e-05
# Time:                        22:21:01   Log-Likelihood:               -0.78714
# No. Observations:                  22   AIC:                             9.574
# Df Residuals:                      18   BIC:                             13.94
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.0750      0.062     -1.215      0.240      -0.205       0.055
# ...

# %%
from src.data_preprocess import do_diff, reverse_diff
diff_df, diff_x0 = do_diff(std_df)

model = regression(diff_df, "population", "urban_population_rate", "gdp_per_capita", "unemployment_rate")
print(model.summary())

population_fitted = model.fittedvalues
population_fitted = pd.DataFrame({population_fitted.name: population_fitted})
population_fitted.columns = ["population"]

print(diff_df)
print(population_fitted)

restored_population_fitted = reverse_diff(population_fitted, diff_x0)
print(restored_population_fitted)


fig, ax = plt.subplots(figsize=(8,6))
ax.plot(std_df.index, std_df["population"], 'o', label='data')
ax.plot(restored_population_fitted.index[1:], restored_population_fitted["population"][1:], 'r--.',label='OLS')
ax.legend(loc='best')
plt.show()

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(diff_df.index, diff_df["population"], 'o', label='data')
ax.plot(population_fitted.index, population_fitted["population"], 'r--.',label='OLS')
ax.legend(loc='best')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             population   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     1.578
# Date:                Wed, 15 May 2024   Prob (F-statistic):              0.229
# Time:                        22:21:09   Log-Likelihood:                 17.091
# No. Observations:                  22   AIC:                            -26.18
# Df Residuals:                      18   BIC:                            -21.82
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.0362      0.120     -0.300      0.767      -0.289       0.217
# ...

# %%
from src.regression import regression
import matplotlib.pyplot as plt

from statsmodels.formula.api import ols

import numpy as np

ratio_diff_df, ratio_x0, diff_x0 = ratio_and_diff(df)

x = pd.DataFrame({df.index.name: df.index})
x.columns = ["time_emb"]
x["time_emb"] = x["time_emb"].astype(float)
x["time_emb"] = x["time_emb"] - 2000
print(x["time_emb"])
x["time_emb"] = 40 * (1 / (x["time_emb"] / 3)) * np.sin((x["time_emb"])) + x["time_emb"]
print(x["time_emb"])
# x["time_emb"] = 2 * np.sin(21 * x["time_emb"]) + 3 * np.cos(21 * x["time_emb"]) - x["time_emb"]
x.index = df.index
# print(x)
df_test = pd.concat([ratio_diff_df, x], axis=1)[:-2]
print(df_test)

formula = "population ~ time_emb"
# formula = "population ~ unemployment_rate"
model = ols(formula, df_test).fit()
print(model.summary())

population_fitted = model.fittedvalues
population_fitted = pd.DataFrame({population_fitted.name: population_fitted})
population_fitted.columns = ["population"]

# restored_population_fitted = reverse_diff(population_fitted, diff_x0)
# print(diff_x0)
# print(restored_population_fitted)
restored_population_fitted = reverse_diff_ratio(population_fitted, diff_x0, ratio_x0)[2:]
print(restored_population_fitted)


fig, ax = plt.subplots(figsize=(8,6))
ax.plot(df.index, df["population"], 'o', label='data')
ax.plot(restored_population_fitted.index, restored_population_fitted["population"], 'r--.',label='OLS')
ax.legend(loc='best')
ax.tick_params(axis='x', labelrotation=62)

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(ratio_diff_df.index, ratio_diff_df["population"], 'o', label='data')
ax.plot(population_fitted.index, population_fitted, 'r--.',label='OLS')
ax.legend(loc='best')
ax.tick_params(axis='x', labelrotation=62)
plt.show()

residuals = df["population"] - restored_population_fitted["population"]
print(residuals)
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(restored_population_fitted.index, residuals[2:], 'x',label='Residual')
ax.tick_params(axis='x', labelrotation=62)
plt.show()
# Out:
# 0      1.0
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# 19    20.0
# 20    21.0
# 21    22.0
# 22    23.0
# Name: time_emb, dtype: float64
# 0     101.976518
# 1      56.557846
# 2       8.644800
# 3     -18.704075
# 4     -18.014183
# 5       0.411690
# 6      18.262627
# 7      22.840374
# 8      14.494913
# 9       3.471747
# 10      0.091016
# 11      6.634271
# 12     16.878465
# 13     22.490920
# 14     20.202303
# 15     13.840725
# 16     10.213665
# 17     12.993418
# 18     19.946593
# 19     25.477672
# 20     25.780889
# 21     21.951720
# 22     18.584937
# Name: time_emb, dtype: float64
#       population  urban_population_rate  gdp_per_capita  unemployment_rate  \
# year
# 2003    0.001393               0.031897        0.147622          -0.051282
# ...
